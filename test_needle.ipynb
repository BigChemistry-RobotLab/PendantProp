# %%
from opentrons_api.load_save_functions import load_settings
from pendantprop.hardware.opentrons.config import Config

settings = load_settings(file_path="config/settings.json")
config = Config(settings=settings)
left_pipette, right_pipette, containers = config.load_all()
# Out:
# 2025-11-19 17:24:34,423 - INFO - Protocol uploaded succesfully.
# 2025-11-19 17:24:41,893 - INFO - Run created succesfully.
# 2025-11-19 17:24:44,751 - INFO - All custom labware definitions added.
# 2025-11-19 17:24:44,752 - INFO - HTTP API initialized successfully.
# 2025-11-19 17:24:45,394 - INFO - Labware loaded successfully.
# 2025-11-19 17:24:45,523 - INFO - Containers loaded successfully.
# 2025-11-19 17:24:49,646 - INFO - Pipettes loaded successfully.

# %%
config.home()
# Out:
# 2025-11-19 17:25:13,922 - INFO - Robot homed.

# %%
left_pipette.pick_up_tip()
# Out:
# 2025-11-19 17:25:19,690 - INFO - Picked up tip.

# %%
left_pipette.aspirate(volume=20, source=containers["7A1"], flow_rate=10)
# Out:
# 2025-11-19 17:25:24,333 - WARNING - Aspiration volume is larger than container volume!
# 2025-11-19 17:25:24,335 - INFO - Aspirated 20 uL from 7A1 with left pipette.

# %%
left_pipette.dispense(volume=19, destination=containers["10A1"], depth_offset=-10.5, update_info=False, flow_rate=1)
# Out:
# 2025-11-19 17:25:46,443 - INFO - Dispensed 19 uL into well 10A1 with left pipette.

# %%
left_pipette.aspirate(volume=10, source=containers["10A1"], depth_offset=-11, update_info=False)

# %%
left_pipette.dispense(volume=20, destination=containers["3A1"])

# %%
left_pipette.home()
