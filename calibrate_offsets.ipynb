# %%
from hardware.opentrons.http_communications import OpentronsAPI
from hardware.cameras import PendantDropCamera
from hardware.sensor.sensor_api import SensorAPI
from hardware.opentrons.configuration import Configuration

opentrons_api = OpentronsAPI()
opentrons_api.initialise()
config = Configuration(http_api=opentrons_api)
labware = config.load_labware()
containers = config.load_containers()
pipettes = config.load_pipettes()
left_pipette = pipettes["left"]
right_pipette = pipettes["right"]
# pendant_drop_camera = PendantDropCamera()
# Out:
# 2025-02-27 17:36:35,088 - INFO - Protocol already uploaded, using existing protocol.
# 2025-02-27 17:37:30,905 - INFO - Run created succesfully (ID: 714e4469-54d4-482d-9af0-674c6377787a).
# 2025-02-27 17:37:32,762 - INFO - All custom labware definitions added.
# 2025-02-27 17:37:33,657 - INFO - Labware loaded successfully.
# 2025-02-27 17:37:33,670 - INFO - Containers loaded successfully.
# 2025-02-27 17:37:37,795 - INFO - Pipettes loaded successfully.

# %%
opentrons_api.home()
# Out:
# 2025-02-27 17:37:57,939 - INFO - Robot homed.

# %% [markdown]
# ### droplet for camera

# %%
left_pipette.pick_up_tip()
left_pipette.aspirate(volume=15, source=containers["7A2"])
left_pipette.air_gap(air_volume=5)

left_pipette.clean_tip()
left_pipette.remove_air_gap(at_drop_stage=True)
# Out:
# 2025-02-27 17:38:15,658 - INFO - Picked up tip.
# 2025-02-27 17:38:18,689 - INFO - Container: aspirated 15 uL from this container with content pure mM water.
# 2025-02-27 17:38:18,705 - INFO - Aspirated 15 uL from 7A2 with left pipette.
# 2025-02-27 17:38:22,459 - INFO - Air gap of 5 uL performed in left pipette.
# 2025-02-27 17:38:27,425 - INFO - Pipette tip cleaned on sponge.
# 2025-02-27 17:38:32,355 - INFO - Air gap of 5 uL removed in left pipette.

# %%
left_pipette.dispense(volume=6, destination=containers["drop_stage"], depth_offset=-23.4, flow_rate=1)
# Out:
# 2025-02-27 17:38:45,639 - INFO - Dispensed 6 uL into well 10A1 with left pipette.

# %%
left_pipette.drop_tip()
# Out:
# 2025-02-27 17:39:37,420 - INFO - Left pipette dropped tip into trash.

# %% [markdown]
# ### Pipette cal

# %%
offset = {"x": -1, "y": 1.4, "z": -10}
# left_pipette.move_to_tip_calibrate(well="A1", offset=offset)
left_pipette.pick_up_tip()
left_pipette.move_to_well_calibrate(container=containers["drop_stage"], well="A1", offset=offset)
# Out:
# 2025-02-26 16:46:47,651 - ERROR - Could not pick up tip as left pipette already has one!

# %%
left_pipette.drop_tip()
# Out:
# 2025-02-26 16:48:01,120 - INFO - Left pipette dropped tip into trash.
