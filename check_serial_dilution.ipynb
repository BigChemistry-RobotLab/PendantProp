# %% [markdown]
# # Formulation check

# %% [markdown]
# Assumed:
# - phenol red saturated solution (concentration set to 1, representing the fraction)
# - formulation plate on location 3

# %%
from hardware.opentrons.opentrons_api import OpentronsAPI
from hardware.opentrons.formulater import Formulater
from hardware.opentrons.configuration import Configuration
from utils.search_containers import get_well_id_solution

opentrons_api = OpentronsAPI()
opentrons_api.initialise()
config = Configuration(opentrons_api=opentrons_api)
labware = config.load_labware()
containers = config.load_containers()
pipettes = config.load_pipettes()
left_pipette = pipettes["left"]
right_pipette = pipettes["right"]
formulater = Formulater(
    left_pipette=left_pipette,
    right_pipette=right_pipette,
    containers=containers,
    labware=labware
)
# Out:
# 2025-07-28 09:31:28,807 - INFO - Protocol already uploaded, using existing protocol.
# 2025-07-28 09:31:36,505 - INFO - Run created succesfully (ID: d7ebd469-ab57-4b2b-9f7f-6da82dc764b4).
# 2025-07-28 09:31:39,218 - INFO - All custom labware definitions added.
# 2025-07-28 09:31:40,690 - INFO - Labware loaded successfully.
# 2025-07-28 09:31:40,733 - INFO - Containers loaded successfully.
# 2025-07-28 09:31:44,989 - INFO - Pipettes loaded successfully.

# %%
opentrons_api.home()
# Out:
# 2025-07-28 09:32:03,330 - INFO - Robot homed.

# %%
well_id_solution = get_well_id_solution(containers=containers, solution_name="phenol red")
print(f"check volume in falcon tube: {containers[well_id_solution].volume_mL} mL")
# Out:
# check volume in falcon tube: 14.0 mL

# %% [markdown]
# well volume is maximal 150 for p300, could be changed in future by changing the pipetting steps

# %%
formulater.serial_dilution(
    row_id="3H",
    solution_name="phenol red",
    n_dilutions=5,
    well_volume=150
)
# Out:
# 2025-07-28 10:24:00,810 - INFO - Start of serial dilution of phenol red in row 3H, with 5 dilutions.
# 2025-07-28 10:24:07,175 - INFO - Picked up tip.
# 2025-07-28 10:24:15,455 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:24:15,456 - INFO - Container: aspirated 150 uL from this container with content pure mM water.
# 2025-07-28 10:24:15,457 - INFO - Aspirated 150 uL from 2A1 with right pipette.
# 2025-07-28 10:24:20,674 - INFO - Container: dispensed 150 uL into this container from source 2A1 containing pure mM water.
# 2025-07-28 10:24:20,675 - INFO - Dispensed 150 uL into well 3H2 with right pipette.
# 2025-07-28 10:24:31,150 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:24:31,151 - INFO - Container: aspirated 150 uL from this container with content pure mM water.
# 2025-07-28 10:24:31,153 - INFO - Aspirated 150 uL from 2A1 with right pipette.
# 2025-07-28 10:24:36,344 - INFO - Container: dispensed 150 uL into this container from source 2A1 containing pure mM water.
# 2025-07-28 10:24:36,345 - INFO - Dispensed 150 uL into well 3H3 with right pipette.
# 2025-07-28 10:24:46,818 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:24:46,820 - INFO - Container: aspirated 150 uL from this container with content pure mM water.
# 2025-07-28 10:24:46,822 - INFO - Aspirated 150 uL from 2A1 with right pipette.
# 2025-07-28 10:24:52,010 - INFO - Container: dispensed 150 uL into this container from source 2A1 containing pure mM water.
# 2025-07-28 10:24:52,012 - INFO - Dispensed 150 uL into well 3H4 with right pipette.
# 2025-07-28 10:25:02,570 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:25:02,572 - INFO - Container: aspirated 150 uL from this container with content pure mM water.
# 2025-07-28 10:25:02,573 - INFO - Aspirated 150 uL from 2A1 with right pipette.
# 2025-07-28 10:25:07,789 - INFO - Container: dispensed 150 uL into this container from source 2A1 containing pure mM water.
# 2025-07-28 10:25:07,791 - INFO - Dispensed 150 uL into well 3H5 with right pipette.
# 2025-07-28 10:25:21,778 - INFO - Right pipette dropped tip into trash.
# 2025-07-28 10:25:28,163 - INFO - Picked up tip.
# 2025-07-28 10:25:36,332 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:25:36,334 - INFO - Container: aspirated 300 uL from this container with content 1 mM phenol red.
# 2025-07-28 10:25:36,336 - INFO - Aspirated 300 uL from 5A1 with right pipette.
# 2025-07-28 10:25:43,168 - INFO - Container: dispensed 300 uL into this container from source 5A1 containing 1 mM phenol red.
# 2025-07-28 10:25:43,170 - INFO - Dispensed 300 uL into well 3H1 with right pipette.
# 2025-07-28 10:25:49,072 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:25:49,075 - INFO - Container: aspirated 150 uL from this container with content 1 mM phenol red.
# 2025-07-28 10:25:49,076 - INFO - Aspirated 150 uL from 3H1 with right pipette.
# 2025-07-28 10:25:51,558 - INFO - Container: dispensed 150 uL into this container from source 3H1 containing 1 mM phenol red.
# 2025-07-28 10:25:51,559 - INFO - Dispensed 150 uL into well 3H2 with right pipette.
# 2025-07-28 10:26:30,628 - INFO - Done with mixing in 3H2 with order after, with volume 125.0 uL, repeated 12 times
# 2025-07-28 10:26:37,803 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:26:37,805 - INFO - Container: aspirated 150 uL from this container with content 0.5 mM phenol red.
# 2025-07-28 10:26:37,806 - INFO - Aspirated 150 uL from 3H2 with right pipette.
# 2025-07-28 10:26:40,291 - INFO - Container: dispensed 150 uL into this container from source 3H2 containing 0.5 mM phenol red.
# 2025-07-28 10:26:40,293 - INFO - Dispensed 150 uL into well 3H3 with right pipette.
# 2025-07-28 10:27:19,197 - INFO - Done with mixing in 3H3 with order after, with volume 125.0 uL, repeated 12 times
# 2025-07-28 10:27:26,330 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:27:26,332 - INFO - Container: aspirated 150 uL from this container with content 0.25 mM phenol red.
# 2025-07-28 10:27:26,334 - INFO - Aspirated 150 uL from 3H3 with right pipette.
# 2025-07-28 10:27:28,831 - INFO - Container: dispensed 150 uL into this container from source 3H3 containing 0.25 mM phenol red.
# 2025-07-28 10:27:28,834 - INFO - Dispensed 150 uL into well 3H4 with right pipette.
# 2025-07-28 10:28:07,888 - INFO - Done with mixing in 3H4 with order after, with volume 125.0 uL, repeated 12 times
# 2025-07-28 10:28:15,072 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:28:15,074 - INFO - Container: aspirated 150 uL from this container with content 0.125 mM phenol red.
# 2025-07-28 10:28:15,076 - INFO - Aspirated 150 uL from 3H4 with right pipette.
# 2025-07-28 10:28:17,559 - INFO - Container: dispensed 150 uL into this container from source 3H4 containing 0.125 mM phenol red.
# 2025-07-28 10:28:17,561 - INFO - Dispensed 150 uL into well 3H5 with right pipette.
# 2025-07-28 10:28:56,498 - INFO - Done with mixing in 3H5 with order after, with volume 125.0 uL, repeated 12 times
# 2025-07-28 10:29:03,700 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:29:03,703 - INFO - Container: aspirated 150 uL from this container with content 0.0625 mM phenol red.
# 2025-07-28 10:29:03,704 - INFO - Aspirated 150 uL from 3H5 with right pipette.
# 2025-07-28 10:29:12,927 - INFO - Touched tip performed, repeated 1 times
# 2025-07-28 10:29:12,928 - INFO - Dispensed 150 uL into well 2B3 with right pipette.
# 2025-07-28 10:29:25,547 - INFO - Right pipette dropped tip into trash.
# 2025-07-28 10:29:25,549 - INFO - End of serial dilution.
