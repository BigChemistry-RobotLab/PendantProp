# %% [markdown]
# # Calibrate pipette

# %% [markdown]
# tips:
# - Advised to first calibrate the pipette via the app, this will make a calibration.json on the raspberry pi, which will always be called first before our own offset. Reason for this, is the blowout function: the plunger reset is always in the calibration of the raspberry pi, not this local function. So to reduce this error, calibrate first via the robot
# - home if something is off, gantry can be moved slightly and your calibration will be off
# - put this script in root

# %%
from opentrons_api.load_save_functions import load_settings
from pendantprop.hardware.opentrons.config import Config

settings = load_settings(file_path="config/settings.json")
# config = Config(settings=settings)
# left_pipette, right_pipette, containers = config.load_all()
# Out:
# {'general_settings': {'simulate': False}, 'robot_settings': {'robot_ip': '169.254.164.30', 'robot_type': 'OT2', 'left_pipette_name': 'p20_single_gen2', 'right_pipette_name': 'p1000_single_gen2', 'left_pipette_offset': {'x': 0, 'y': 0, 'z': 0}, 'right_pipette_offset': {'x': -0.2, 'y': 1, 'z': 0}, 'well_depth_mm': 1}, 'file_settings': {'exp_tag': 'example', 'output_folder': 'output', 'output_folder_pictures': 'output/pictures', 'meta_data_folder': 'meta_data', 'data_folder': 'data', 'sample_info_filepath': 'config/info/sample_info.csv', 'container_data_folder': 'container_data', 'config_filepath': 'config/layouts/layout.csv', 'custom_labware_folder': 'config/custom_labware', 'plot_folder_server': 'src/pendantprop/server/static/plots_cache'}, 'wash_settings': {'wash_volume_ul': 300, 'wash_repeats': 3, 'name_wash_container': 'water_wash', 'name_trash_container': 'trash', 'name_wash_plate': 'wash plate', 'mixing_volume_ul': 20, 'mix_repeats': 5}, 'sensor_settings': {'serial_port': 'COM3', 'flask_port': 5001, 'baud_rate': 9600, 'read_interval_s': 2}, 'pendant_drop_settings': {'explore_points': 5, 'worthington_limit_lower': 0.4, 'worthington_limit_upper': 0.9, 'initial_drop_volume': 5, 'check_time': 1, 'equilibration_time': 60, 'max_measure_time': 120, 'max_retries': 5, 'drop_volume_decrease_after_retry': 0.35, 'drop_volume_increase_resolution': 0.2, 'flow_rate': 0.1, 'pendant_drop_depth_offset': -11, 'well_id_drop_stage': '10A1', 'n_equilibration_points': 100}, 'camera_settings': {'capture_interval': 1}, 'image_analysis_settings': {'diameter_needle_mm': 1.45, 'diameter_needle_px': 360, 'diameter_tolerance_percent': 5, 'st_water': 72.37, 'density': 0.789, 'gravity_constant': 9.80665}}

# %%
pipette = left_pipette

# %%
config.home()
# Out:
# 2025-11-13 15:11:02,389 - INFO - Robot homed.

# %% [markdown]
# ### set your offset

# %%
offset = {
    'x': 0.0,
    'y': 0.0,
    'z': 0.0
}

# %% [markdown]
# ### move to tip to check offset

# %%
pipette.move_to_tip_calibrate(well="A1", offset=offset)

# %%
pipette.move_to_tip_calibrate(well="A12", offset=offset)

# %%
pipette.move_to_tip_calibrate(well="H1", offset=offset)

# %%
pipette.move_to_tip_calibrate(well="H12", offset=offset)

# %% [markdown]
# ### pick up tip

# %% [markdown]
# watch out: the offset in the settings will be used

# %%
pipette.pick_up_tip()
# Out:
# 2025-11-13 15:11:47,967 - INFO - Picked up tip.

# %%
pipette.drop_tip()

# %% [markdown]
# ### move to well to check offset
# - plate assumed to be location 3
# - tip needed!

# %%
offset = {
    'x': 0,
    'y': 0,
    'z': -11
}
pipette.move_to_well_calibrate(containers["10A1"], offset=offset)

# %%
pipette.move_to_well_calibrate(containers["3A1"], offset=offset)

# %%
pipette.move_to_well_calibrate(containers["3A12"], offset=offset)

# %%
pipette.move_to_well_calibrate(containers["3H1"], offset=offset)

# %%
pipette.move_to_well_calibrate(containers["3H12"], offset=offset)

# %%
pipette.move
