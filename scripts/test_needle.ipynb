# %%
from opentrons_api.load_save_functions import load_settings
from pendantprop.hardware.opentrons.config import Config

settings = load_settings(file_path="config/settings.json")
config = Config(settings=settings)
left_pipette, right_pipette, containers = config.load_all()
# Out:
# 2025-11-18 17:01:34,665 - INFO - Protocol uploaded succesfully.
# 2025-11-18 17:01:41,661 - INFO - Run created succesfully.
# 2025-11-18 17:01:44,595 - INFO - All custom labware definitions added.
# 2025-11-18 17:01:44,596 - INFO - HTTP API initialized successfully.
# 2025-11-18 17:01:45,389 - INFO - Labware loaded successfully.
# 2025-11-18 17:01:45,474 - INFO - Containers loaded successfully.
# 2025-11-18 17:01:49,679 - INFO - Pipettes loaded successfully.

# %%
config.home()
# Out:
# 2025-11-18 14:28:45,082 - INFO - Robot homed.

# %%
left_pipette.pick_up_tip()
# Out:
# 2025-11-18 17:01:55,475 - INFO - Picked up tip.

# %%
left_pipette.aspirate(volume=20, source=containers["7A1"], flow_rate=10)
# Out:
# 2025-11-18 17:02:18,692 - WARNING - Aspiration volume is larger than container volume!
# 2025-11-18 17:02:18,693 - INFO - Aspirated 20 uL from 7A1 with left pipette.

# %%
left_pipette.dispense(volume=4, destination=containers["10A1"], depth_offset=-10.5, update_info=False, flow_rate=1)
# Out:
# 2025-11-18 17:03:48,310 - INFO - Dispensed 4 uL into well 10A1 with left pipette.

# %%
left_pipette.aspirate(volume=10, source=containers["10A1"], depth_offset=-11, update_info=False)

# %%
left_pipette.dispense(volume=20, destination=containers["3A1"])
# Out:
# 2025-11-18 14:23:06,881 - WARNING - Source 7A1 of the dispensing step is empty.
# 2025-11-18 14:23:06,882 - WARNING - Container: source of the dispensing step is empty.
# 2025-11-18 14:23:06,883 - INFO - Dispensed 20 uL into well 3A1 with left pipette.

# %%
left_pipette.home()
