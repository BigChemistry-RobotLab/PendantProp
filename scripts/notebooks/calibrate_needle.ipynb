# %% [markdown]
# # Calibrate Needle

# %% [markdown]
# ### Initialize

# %%
from opentrons_api.load_save_functions import load_settings
from pendantprop.hardware.opentrons.config import Config

settings = load_settings(file_path="config/settings.json")
config = Config(settings=settings)
left_pipette, right_pipette, containers = config.load_all()
# Out:
# 2025-12-15 14:13:39,223 - INFO - Protocol uploaded succesfully.
# 2025-12-15 14:13:46,504 - INFO - Run created succesfully.
# 2025-12-15 14:13:49,378 - INFO - All custom labware definitions added.
# 2025-12-15 14:13:49,380 - INFO - HTTP API initialized successfully.
# 2025-12-15 14:13:50,315 - INFO - Labware loaded successfully.
# 2025-12-15 14:13:50,528 - INFO - Containers loaded successfully.
# 2025-12-15 14:13:54,723 - INFO - Pipettes loaded successfully.

# %%
config.home()
# Out:
# 2025-12-15 14:14:28,341 - INFO - Robot homed.

# %% [markdown]
# ### Create pendant drop
# 1. assumed water in 7A1 well plate (can change if prefered)
# 2. check depth offset

# %%
left_pipette.pick_up_tip()
# Out:
# 2025-12-15 14:14:37,526 - INFO - Picked up tip.

# %%
left_pipette.aspirate(volume=20, source=containers["8A1"], flow_rate=10)
# Out:
# 2025-12-15 14:14:46,759 - WARNING - Aspiration volume is larger than container volume!
# 2025-12-15 14:14:46,760 - INFO - Aspirated 20 uL from 8A1 with left pipette.

# %%
left_pipette.dispense(volume=19, destination=containers["10A1"], depth_offset=-22, update_info=False, flow_rate=1)
# Out:
# 2025-12-15 14:15:27,408 - INFO - Dispensed 19 uL into well 10A1 with left pipette.

# %% [markdown]
# ### Camera
# 1. put video stream on: [video_stream.py](scripts/video_stream.py)
# 2. check focus
# 3. capture picture with [capture_image.py](scripts/capture_image.py)
# 4. check diameter px with fiji
# 5. check if image analys works with [test_image_analyzer.py](scripts/test_image_analyzer.py)

# %% [markdown]
# ### Return pendant drop

# %%
left_pipette.aspirate(volume=19, source=containers["10A1"], depth_offset=-22, update_info=False)
# Out:
# 2025-12-15 14:17:07,482 - INFO - Aspirated 19 uL from 10A1 with left pipette.

# %%
left_pipette.dispense(volume=20, destination=containers["8A1"])
# Out:
# 2025-12-15 14:17:16,189 - WARNING - Source 8A1 of the dispensing step is empty.
# 2025-12-15 14:17:16,191 - WARNING - Container: source of the dispensing step is empty.
# 2025-12-15 14:17:16,193 - INFO - Dispensed 20 uL into well 8A1 with left pipette.

# %%
left_pipette.home()
